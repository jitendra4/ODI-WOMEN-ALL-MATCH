# %% [markdown]
# # Top 10 ODI teams in WOMEN’s cricket along with the records for matches, points and RATING

# %%
# !pip install requests
# !pip install bs4

# %%
#importing the requried Libraries
from bs4 import BeautifulSoup
import requests

# %%
page= requests.get("https://www.icc-cricket.com/rankings/womens/team-rankings/odi")

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta name="twitter:title" content="ICC Ranking for ODI teams International Cricket Council"/>\n<meta property="og:type" content="website"/>\n<meta property="twitter:card" content="summary_large_image"/>\n<meta name="description" content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta property="twitter:site" content="@icc"/>\n<meta name="twitter:description" content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta name="twitter:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg"/>\n<meta property="og:title" content="ICC Ranking for ODI teams International Cricket Council"/>\n<meta property="og:image" content="https://w
# ...

# %%
soup = BeautifulSoup(page.content,'html.parser')

# %%
team_name=[]
team_match=[]
team_point=[]
team_rating=[]

# %%
# let extract at the tags having the team-name
name=soup.find_all('span',class_="u-hide-phablet")
name
# Out:
# [<span class="u-hide-phablet">Australia</span>,
#  <span class="u-hide-phablet">India</span>,
#  <span class="u-hide-phablet">England</span>,
#  <span class="u-hide-phablet">South Africa</span>,
#  <span class="u-hide-phablet">New Zealand</span>,
#  <span class="u-hide-phablet">West Indies</span>,
#  <span class="u-hide-phablet">Pakistan</span>,
#  <span class="u-hide-phablet">Bangladesh</span>,
#  <span class="u-hide-phablet">Sri Lanka</span>,
#  <span class="u-hide-phablet">Ireland</span>,
#  <span class="icn icn-facebook-circle u-hide-phablet"></span>,
#  <span class="icn icn-twitter-circle u-hide-phablet"></span>,
#  <span class="icn icn-instagram-circle u-hide-phablet"></span>,
#  <span class="icn icn-youtube-circle u-hide-phablet"></span>,
#  <span class="icn icn-tiktok-circle u-hide-phablet"></span>]

# %%
for i in name:
    team_name.append(i.get_text())
team_name
# Out:
# ['Australia',
#  'India',
#  'England',
#  'South Africa',
#  'New Zealand',
#  'West Indies',
#  'Pakistan',
#  'Bangladesh',
#  'Sri Lanka',
#  'Ireland',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
# let extract at the tags having the match-name
match=soup.find_all('td',class_="table-body__cell u-center-text")
match[0:4]
# Out:
# [<td class="table-body__cell u-center-text">15</td>,
#  <td class="table-body__cell u-center-text">1,812</td>,
#  <td class="table-body__cell u-center-text">14</td>,
#  <td class="table-body__cell u-center-text">1,670</td>]

# %%
# let extract at the tags having the match-name
match=soup.find_all('td',class_="table-body__cell u-center-text")
match[0:4]
# Out:
# [<td class="table-body__cell u-center-text">15</td>,
#  <td class="table-body__cell u-center-text">1,812</td>,
#  <td class="table-body__cell u-center-text">14</td>,
#  <td class="table-body__cell u-center-text">1,670</td>]

# %%
for i in match:
    team_match.append(i.get_text())
team_match
# Out:
# ['15',
#  '1,812',
#  '14',
#  '1,670',
#  '16',
#  '1,713',
#  '15',
#  '1,384',
#  '12',
#  '1,025',
#  '12',
#  '927',
#  '5',
#  '306',
#  '11',
#  '519',
#  '2',
#  '25',
#  '15',
#  '1,812',
#  '14',
#  '1,670',
#  '16',
#  '1,713',
#  '15',
#  '1,384',
#  '12',
#  '1,025',
#  '12',
#  '927',
#  '5',
#  '306',
#  '11',
#  '519',
#  '2',
#  '25',
#  '15',
#  '1,812',
#  '14',
#  '1,670',
#  '16',
#  '1,713',
#  '15',
#  '1,384',
#  '12',
#  '1,025',
#  '12',
#  '927',
#  '5',
#  '306',
#  '11',
#  '519',
#  '2',
#  '25']

# %%
# let extract at the tags having the rating-name
rating=soup.find_all('td',class_="table-body__cell u-text-right rating")
rating[0:4]
# Out:
# [<td class="table-body__cell u-text-right rating">121</td>,
#  <td class="table-body__cell u-text-right rating">119</td>,
#  <td class="table-body__cell u-text-right rating">107</td>,
#  <td class="table-body__cell u-text-right rating">92</td>]

# %%
for i in rating:
    team_rating.append(i.get_text())
team_rating
# Out:
# ['121', '119', '107', '92', '85', '77', '61', '47', '13']

# %%
print(len(name),
      len(match),
      len(rating))
# Out:
# 15 18 9

# %%
import pandas as pd
team=pd.DataFrame({})
team['team_name']=name[0:8]
team['team_match']=match[0:8]
team['team_rating']=rating[0:8]
team
# Out:
#         team_name team_match team_rating
# 0     [Australia]       [15]       [121]
# 1         [India]    [1,812]       [119]
# 2       [England]       [14]       [107]
# 3  [South Africa]    [1,670]        [92]
# 4   [New Zealand]       [16]        [85]
# 5   [West Indies]    [1,713]        [77]
# 6      [Pakistan]       [15]        [61]
# 7    [Bangladesh]    [1,384]        [47]

# %% [markdown]
# # Top 10 ODI Batsmen in women along with the records of their team and rating.

# %%
page= requests.get("https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting?at=2021-01-10")

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta name="twitter:title" content="Live Cricket Scores & News International Cricket Council"/>\n<meta property="og:type" content="website"/>\n<meta property="twitter:card" content="summary_large_image"/>\n<meta name="description" content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council."/>\n<meta property="twitter:site" content="@icc"/>\n<meta name="twitter:description" content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council."/>\n<meta name="twitter:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg"/>\n<meta property="og:title" content="Live Cricket Scores & News International Cricket Council"/>\n<meta property="og:image" content="https://www.icc-cricket.com/resources/ver/i/elements/defa
# ...

# %%
soup= BeautifulSoup(page.content,'html.parser')

# %%
batsman_name=[]
team_name=[]
batsman_rating=[]

# %%
# let extract at the tags having the batsman-name
batsman=soup.find_all('td',class_="table-body__cell rankings-table__name name")
batsman[0:4]
# Out:
# [<td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/573">Stafanie Taylor</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/466">Alyssa Healy</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/1809">Smriti Mandhana</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/487">Amy Satterthwaite</a>
#  </td>]

# %%
for i in batsman:
    batsman_name.append(i.get_text().replace("\n",""))
batsman_name
# Out:
# ['Stafanie Taylor',
#  'Alyssa Healy',
#  'Smriti Mandhana',
#  'Amy Satterthwaite',
#  'Tammy Beaumont',
#  'Ellyse Perry',
#  'Lizelle Lee',
#  'Laura Wolvaardt',
#  'Mithali Raj',
#  'Natalie Sciver',
#  'Chamari Athapaththu',
#  'Rachael Haynes',
#  'Suzie Bates',
#  'Sophie Devine',
#  'Heather Knight',
#  'Beth Mooney',
#  'Nahida Khan',
#  'Mignon du Preez',
#  'Harmanpreet Kaur',
#  'Dane van Niekerk',
#  'Deepti Sharma',
#  'Bismah Maroof',
#  'Javeria Khan',
#  'Poonam Raut',
#  'Marizanne Kapp',
#  'Chloe-Lesleigh Tryon',
#  'Amy Jones',
#  'Nicole Bolton',
#  'Katie Perkins',
#  'Hayley Matthews',
#  'Danielle Wyatt',
#  'Fargana Hoque',
#  'Sune Luus',
#  'Rumana Ahmed',
#  'Jemimah Rodriques',
#  'Ashleigh Gardner',
#  'Katey Martin',
#  'Trisha Chetty',
#  'Jess Jonassen',
#  'Shikha Pandey',
#  'Katherine Brunt',
#  'Harshitha Madavi',
#  'Fran Wilson',
#  'Jhulan Goswami',
#  'Rachel Priest',
#  'Maddie Green',
#  'Shemaine Campbelle',
#  'Dilani Manodara',
# ...

# %%
# let extract at the tags having the team-name
team=soup.find_all('td',class_="table-body__cell nationality-logo rankings-table__team")
team[0:4]
# Out:
# [<td class="table-body__cell nationality-logo rankings-table__team">
#  <span class="flag-15 table-body_logo WI"></span>
#  <span class="table-body__logo-text">WI</span>
#  </td>,
#  <td class="table-body__cell nationality-logo rankings-table__team">
#  <span class="flag-15 table-body_logo AUS"></span>
#  <span class="table-body__logo-text">AUS</span>
#  </td>,
#  <td class="table-body__cell nationality-logo rankings-table__team">
#  <span class="flag-15 table-body_logo IND"></span>
#  <span class="table-body__logo-text">IND</span>
#  </td>,
#  <td class="table-body__cell nationality-logo rankings-table__team">
#  <span class="flag-15 table-body_logo NZ"></span>
#  <span class="table-body__logo-text">NZ</span>
#  </td>]

# %%
for i in team:
    team_name.append(i.get_text().replace("/n",""))
team_name
# Out:
# ['\n\nWI\n',
#  '\n\nAUS\n',
#  '\n\nIND\n',
#  '\n\nNZ\n',
#  '\n\nENG\n',
#  '\n\nAUS\n',
#  '\n\nSA\n',
#  '\n\nSA\n',
#  '\n\nIND\n',
#  '\n\nENG\n',
#  '\n\nSL\n',
#  '\n\nAUS\n',
#  '\n\nNZ\n',
#  '\n\nNZ\n',
#  '\n\nENG\n',
#  '\n\nAUS\n',
#  '\n\nPAK\n',
#  '\n\nSA\n',
#  '\n\nIND\n',
#  '\n\nSA\n',
#  '\n\nIND\n',
#  '\n\nPAK\n',
#  '\n\nPAK\n',
#  '\n\nIND\n',
#  '\n\nSA\n',
#  '\n\nSA\n',
#  '\n\nENG\n',
#  '\n\nAUS\n',
#  '\n\nNZ\n',
#  '\n\nWI\n',
#  '\n\nENG\n',
#  '\n\nBAN\n',
#  '\n\nSA\n',
#  '\n\nBAN\n',
#  '\n\nIND\n',
#  '\n\nAUS\n',
#  '\n\nNZ\n',
#  '\n\nSA\n',
#  '\n\nAUS\n',
#  '\n\nIND\n',
#  '\n\nENG\n',
#  '\n\nSL\n',
#  '\n\nENG\n',
#  '\n\nIND\n',
#  '\n\nNZ\n',
#  '\n\nNZ\n',
#  '\n\nWI\n',
#  '\n\nSL\n',
#  '\n\nBAN\n',
#  '\n\nPAK\n',
#  '\n\nWI\n',
#  '\n\nWI\n',
#  '\n\nPAK\n',
#  '\n\nPAK\n',
#  '\n\nWI\n',
#  '\n\nSA\n',
#  '\n\nIND\n',
#  '\n\nNZ\n',
#  '\n\nIND\n',
#  '\n\nSL\n',
#  '\n\nWI\n',
#  '\n\nIND\n',
#  '\n\nBAN\n',
#  '\n\nNZ\n',
# ...

# %%
team[0].get_text().replace("\n","")
# Out:
# 'WI'

# %%
# let extract at the tags having the rating-name
rating=soup.find_all('td',class_="table-body__cell rating")
rating[0:4]
# Out:
# [<td class="table-body__cell rating">746</td>,
#  <td class="table-body__cell rating">741</td>,
#  <td class="table-body__cell rating">732</td>,
#  <td class="table-body__cell rating">723</td>]

# %%
for i in rating:
    batsman_rating.append(i.get_text().replace("\n",""))
batsman_rating
# Out:
# ['746',
#  '741',
#  '732',
#  '723',
#  '716',
#  '691',
#  '690',
#  '689',
#  '687',
#  '670',
#  '667',
#  '655',
#  '651',
#  '649',
#  '641',
#  '603',
#  '600',
#  '597',
#  '594',
#  '585',
#  '562',
#  '553',
#  '551',
#  '543',
#  '528',
#  '514',
#  '511',
#  '484',
#  '466',
#  '461',
#  '448',
#  '445',
#  '437',
#  '437',
#  '409',
#  '399',
#  '396',
#  '385',
#  '375',
#  '371',
#  '368',
#  '353',
#  '352',
#  '325',
#  '322',
#  '320',
#  '319',
#  '319',
#  '317',
#  '299',
#  '292',
#  '281',
#  '280',
#  '280',
#  '276',
#  '275',
#  '269',
#  '269',
#  '266',
#  '261',
#  '252',
#  '248',
#  '244',
#  '240',
#  '239',
#  '236',
#  '227',
#  '226',
#  '224',
#  '221',
#  '211',
#  '208',
#  '205',
#  '201',
#  '198',
#  '195',
#  '195',
#  '191',
#  '191',
#  '188',
#  '186',
#  '186',
#  '184',
#  '181',
#  '179',
#  '177',
#  '175',
#  '170',
#  '166',
#  '164',
#  '163',
#  '162',
#  '162',
#  '161',
#  '161',
#  '151',
#  '149',
#  '145',
#  '145']

# %%
print(len(batsman),
      len(team),
      len(rating))
# Out:
# 99 99 99

# %%
import pandas as pd
ODI=pd.DataFrame({})
ODI['batsman_name']=batsman
ODI['team_name']=team
ODI['batsman_rating']=rating
ODI
# Out:
#                      batsman_name                team_name batsman_rating
# 0     [\n, [Stafanie Taylor], \n]   [\n, [], \n, [WI], \n]          [746]
# 1        [\n, [Alyssa Healy], \n]  [\n, [], \n, [AUS], \n]          [741]
# 2     [\n, [Smriti Mandhana], \n]  [\n, [], \n, [IND], \n]          [732]
# 3   [\n, [Amy Satterthwaite], \n]   [\n, [], \n, [NZ], \n]          [723]
# 4      [\n, [Tammy Beaumont], \n]  [\n, [], \n, [ENG], \n]          [716]
# ..                            ...                      ...            ...
# 94     [\n, [Anisa Mohammed], \n]   [\n, [], \n, [WI], \n]          [161]
# 95     [\n, [Ayabonga Khaka], \n]   [\n, [], \n, [SA], \n]          [151]
# 96     [\n, [Britney Cooper], \n]   [\n, [], \n, [WI], \n]          [149]
# 97     [\n, [Tahlia McGrath], \n]  [\n, [], \n, [AUS], \n]          [145]
# 98        [\n, [Sidra Nawaz], \n]  [\n, [], \n, [PAK], \n]          [145]
#
# [99 rows x 3 columns]

# %% [markdown]
# # Top 10 women’s ODI all-rounder along with the records of their team and rating

# %%
page= requests.get("https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder")

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta name="twitter:title" content="Live Cricket Scores & News International Cricket Council"/>\n<meta property="og:type" content="website"/>\n<meta property="twitter:card" content="summary_large_image"/>\n<meta name="description" content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council."/>\n<meta property="twitter:site" content="@icc"/>\n<meta name="twitter:description" content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council."/>\n<meta name="twitter:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg"/>\n<meta property="og:title" content="Live Cricket Scores & News International Cricket Council"/>\n<meta property="og:image" content="https://www.icc-cricket.com/resources/ver/i/elements/defa
# ...

# %%
allrounder_name=[]
team_name=[]
allrounder_rating=[]

# %%
# let extract at the tags having the ALLROUNDER-name
allrounder=soup.find_all('td',class_="table-body__cell rankings-table__name name")
allrounder[0:4]
# Out:
# [<td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/573">Stafanie Taylor</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/466">Alyssa Healy</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/1809">Smriti Mandhana</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/487">Amy Satterthwaite</a>
#  </td>]

# %%
for i in allrounder:
    allrounder_name.append(i.get_text().replace("\n",""))
allrounder_name
# Out:
# ['Stafanie Taylor',
#  'Alyssa Healy',
#  'Smriti Mandhana',
#  'Amy Satterthwaite',
#  'Tammy Beaumont',
#  'Ellyse Perry',
#  'Lizelle Lee',
#  'Laura Wolvaardt',
#  'Mithali Raj',
#  'Natalie Sciver',
#  'Chamari Athapaththu',
#  'Rachael Haynes',
#  'Suzie Bates',
#  'Sophie Devine',
#  'Heather Knight',
#  'Beth Mooney',
#  'Nahida Khan',
#  'Mignon du Preez',
#  'Harmanpreet Kaur',
#  'Dane van Niekerk',
#  'Deepti Sharma',
#  'Bismah Maroof',
#  'Javeria Khan',
#  'Poonam Raut',
#  'Marizanne Kapp',
#  'Chloe-Lesleigh Tryon',
#  'Amy Jones',
#  'Nicole Bolton',
#  'Katie Perkins',
#  'Hayley Matthews',
#  'Danielle Wyatt',
#  'Fargana Hoque',
#  'Sune Luus',
#  'Rumana Ahmed',
#  'Jemimah Rodriques',
#  'Ashleigh Gardner',
#  'Katey Martin',
#  'Trisha Chetty',
#  'Jess Jonassen',
#  'Shikha Pandey',
#  'Katherine Brunt',
#  'Harshitha Madavi',
#  'Fran Wilson',
#  'Jhulan Goswami',
#  'Rachel Priest',
#  'Maddie Green',
#  'Shemaine Campbelle',
#  'Dilani Manodara',
# ...

# %%
# let extract at the tags having the team-name
team=soup.find_all('span',class_="table-body__logo-text")
team[0:4]
# Out:
# [<span class="table-body__logo-text">WI</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">NZ</span>]

# %%
for i in team:
    team_name.append(i.get_text().replace("\n",""))
team_name
# Out:
# ['WI',
#  'AUS',
#  'IND',
#  'NZ',
#  'ENG',
#  'AUS',
#  'SA',
#  'SA',
#  'IND',
#  'ENG',
#  'SL',
#  'AUS',
#  'NZ',
#  'NZ',
#  'ENG',
#  'AUS',
#  'PAK',
#  'SA',
#  'IND',
#  'SA',
#  'IND',
#  'PAK',
#  'PAK',
#  'IND',
#  'SA',
#  'SA',
#  'ENG',
#  'AUS',
#  'NZ',
#  'WI',
#  'ENG',
#  'BAN',
#  'SA',
#  'BAN',
#  'IND',
#  'AUS',
#  'NZ',
#  'SA',
#  'AUS',
#  'IND',
#  'ENG',
#  'SL',
#  'ENG',
#  'IND',
#  'NZ',
#  'NZ',
#  'WI',
#  'SL',
#  'BAN',
#  'PAK',
#  'WI',
#  'WI',
#  'PAK',
#  'PAK',
#  'WI',
#  'SA',
#  'IND',
#  'NZ',
#  'IND',
#  'SL',
#  'WI',
#  'IND',
#  'BAN',
#  'NZ',
#  'ENG',
#  'AUS',
#  'PAK',
#  'SL',
#  'WI',
#  'BAN',
#  'SL',
#  'ENG',
#  'SL',
#  'WI',
#  'IND',
#  'AUS',
#  'SL',
#  'SA',
#  'NZ',
#  'WI',
#  'PAK',
#  'WI',
#  'NZ',
#  'BAN',
#  'ENG',
#  'NZ',
#  'WI',
#  'SA',
#  'BAN',
#  'NZ',
#  'AUS',
#  'NZ',
#  'IND',
#  'SL',
#  'WI',
#  'SA',
#  'WI',
#  'AUS',
#  'PAK']

# %%
# let extract at the tags having the rating-name
rating=soup.find_all('td',class_="table-body__cell rating")
rating[0:4]
# Out:
# [<td class="table-body__cell rating">746</td>,
#  <td class="table-body__cell rating">741</td>,
#  <td class="table-body__cell rating">732</td>,
#  <td class="table-body__cell rating">723</td>]

# %%
for i in rating:
    allrounder_rating.append(i.get_text().replace("\n",""))
allrounder_rating
# Out:
# ['746',
#  '741',
#  '732',
#  '723',
#  '716',
#  '691',
#  '690',
#  '689',
#  '687',
#  '670',
#  '667',
#  '655',
#  '651',
#  '649',
#  '641',
#  '603',
#  '600',
#  '597',
#  '594',
#  '585',
#  '562',
#  '553',
#  '551',
#  '543',
#  '528',
#  '514',
#  '511',
#  '484',
#  '466',
#  '461',
#  '448',
#  '445',
#  '437',
#  '437',
#  '409',
#  '399',
#  '396',
#  '385',
#  '375',
#  '371',
#  '368',
#  '353',
#  '352',
#  '325',
#  '322',
#  '320',
#  '319',
#  '319',
#  '317',
#  '299',
#  '292',
#  '281',
#  '280',
#  '280',
#  '276',
#  '275',
#  '269',
#  '269',
#  '266',
#  '261',
#  '252',
#  '248',
#  '244',
#  '240',
#  '239',
#  '236',
#  '227',
#  '226',
#  '224',
#  '221',
#  '211',
#  '208',
#  '205',
#  '201',
#  '198',
#  '195',
#  '195',
#  '191',
#  '191',
#  '188',
#  '186',
#  '186',
#  '184',
#  '181',
#  '179',
#  '177',
#  '175',
#  '170',
#  '166',
#  '164',
#  '163',
#  '162',
#  '162',
#  '161',
#  '161',
#  '151',
#  '149',
#  '145',
#  '145']

# %%
print(len(allrounder),
     len(team),
     len(rating))
# Out:
# 99 99 99

# %%
import pandas as pd
ODI=pd.DataFrame({})
ODI['allrounder_name']=allrounder[0:10]
ODI['team_name']=team[0:10]
ODI['allrounder_rating']=rating[0:10]
ODI
# Out:
#                  allrounder_name team_name allrounder_rating
# 0    [\n, [Stafanie Taylor], \n]      [WI]             [746]
# 1       [\n, [Alyssa Healy], \n]     [AUS]             [741]
# 2    [\n, [Smriti Mandhana], \n]     [IND]             [732]
# 3  [\n, [Amy Satterthwaite], \n]      [NZ]             [723]
# 4     [\n, [Tammy Beaumont], \n]     [ENG]             [716]
# 5       [\n, [Ellyse Perry], \n]     [AUS]             [691]
# 6        [\n, [Lizelle Lee], \n]      [SA]             [690]
# 7    [\n, [Laura Wolvaardt], \n]      [SA]             [689]
# 8        [\n, [Mithali Raj], \n]     [IND]             [687]
# 9     [\n, [Natalie Sciver], \n]     [ENG]             [670]
